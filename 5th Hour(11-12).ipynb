# %%
import pandas as pd
import numpy as np

# %%
## read df
df_1st_hour = pd.read_csv(r'C:\Users\arvinmvn\Desktop\Split Throughput\recent\1st hr.csv')
df_2nd_hour = pd.read_csv(r'C:\Users\arvinmvn\Desktop\Split Throughput\recent\2nd hr.csv')
df_3rd_hour = pd.read_csv(r'C:\Users\arvinmvn\Desktop\Split Throughput\recent\3rd hr.csv')
df_4th_hour = pd.read_csv(r'C:\Users\arvinmvn\Desktop\Split Throughput\recent\4th hr.csv')
df_5th_hour = pd.read_csv(r'C:\Users\arvinmvn\Desktop\Split Throughput\recent\5th hr.csv')
df_tm = pd.read_excel(r'C:\Users\arvinmvn\Desktop\Split Throughput\Radhika Org TM-OM-SM mapping.xlsx')
df_5th_hour.head()
# Out:
#    DA Login First Login Time      Current Status  \
# 0    aanbub   9/24/2021 1:28  mercury_production
# 1     aarjk   9/24/2021 4:29  mercury_production
# 2  abdarsha   9/24/2021 1:36             project
# 3   adithia   9/24/2021 4:30  mercury_production
# 4   adityna   9/24/2021 1:29  mercury_production
#
#                                       Skill Value ID     UPH  AHT (In sec)  \
# 0  ads_central_skill_type_PresenceDetectionSpecia...  60.375     27.284721
# 1                                                NaN  15.125     29.281983
# 2          ads_central_skill_type_core_transcription   0.000           NaN
# 3                                                NaN   0.625     59.616000
# 4                                                NaN  39.375     42.427429
#
#      Velocity  Utilization %   NPT %  Processed Units  ...  Manual Skip Hours  \
# 0  131.941978         1.1380  0.0000              483  ...             0.0006
# 1  122.942491         0.8412  0.0000              121  ...             0.0000
# 2         NaN         0.0012  0.9155                0  ...             0.0000
# 3   60.386473         0.0869  0.0000                5  ...             0.0125
# 4   84.850770         1.0541  0.0535              315  ...             0.0836
#
#    Non Mercury Processing Hours  Staff Hours     NPT  Idle No Data  \
# 0                        0.0091            8  0.0000           0.0
# 1                       -0.0955            8  0.0000           0.0
# 2                        0.0050            8  3.7389           0.0
# 3                        0.0077            8  0.0000           0.0
# 4                        0.3452            8  0.2075           0.0
#
#    Training Hours  Lost Hours  System Issue  System Latency  \
# 0             0.0      0.0000           0.0          0.0095
# 1             0.0      0.1720           0.0          0.0230
# 2             0.0      0.3398           0.0          0.0000
# 3             0.0      0.9895           0.0          0.0037
# 4             0.0      0.0215           0.0          0.0295
#
#    Schedule Non Adherence
# 0                  0.0000
# 1                  0.0684
# 2                  0.3398
# 3                  0.9895
# 4                  0.0215
#
# [5 rows x 24 columns]

# %%
## insert time range column
df_1st_hour.insert(2, "Time Range",'07-08')
df_2nd_hour.insert(2, "Time Range",'08-09')
df_3rd_hour.insert(2, "Time Range",'09-10')
df_4th_hour.insert(2, "Time Range",'10-11')
df_5th_hour.insert(2, "Time Range",'11-12')

# %%
## insert shift
df_1st_hour.insert(3, "Shift",'Morning')
df_2nd_hour.insert(3, "Shift",'Morning')
df_3rd_hour.insert(3, "Shift",'Morning')
df_4th_hour.insert(3, "Shift",'Morning')
df_5th_hour.insert(3, "Shift",'Morning')

# %%
## insert process units
df_1st_hour['Processed Units']=df_1st_hour['Processed Units']
df_2nd_hour['Processed Units']=df_2nd_hour['Processed Units']-df_1st_hour['Processed Units']
df_3rd_hour['Processed Units']=df_3rd_hour['Processed Units']-df_2nd_hour['Processed Units']-df_1st_hour['Processed Units']
df_4th_hour['Processed Units']=df_4th_hour['Processed Units']-df_3rd_hour['Processed Units']-df_2nd_hour['Processed Units']-df_1st_hour['Processed Units']
df_5th_hour['Processed Units']=df_5th_hour['Processed Units']-df_4th_hour['Processed Units']-df_3rd_hour['Processed Units']-df_2nd_hour['Processed Units']-df_1st_hour['Processed Units']

# %%
## insert manual skip hours

df_1st_hour['Manual Skip Hours']=df_1st_hour['Manual Skip Hours']
df_2nd_hour['Manual Skip Hours']=df_2nd_hour['Manual Skip Hours']-df_1st_hour['Manual Skip Hours']
df_3rd_hour['Manual Skip Hours']=df_3rd_hour['Manual Skip Hours']-df_2nd_hour['Manual Skip Hours']-df_1st_hour['Manual Skip Hours']
df_4th_hour['Manual Skip Hours']=df_4th_hour['Manual Skip Hours']-df_3rd_hour['Manual Skip Hours']-df_2nd_hour['Manual Skip Hours']-df_1st_hour['Manual Skip Hours']
df_5th_hour['Manual Skip Hours']=df_5th_hour['Manual Skip Hours']-df_4th_hour['Manual Skip Hours']-df_3rd_hour['Manual Skip Hours']-df_2nd_hour['Manual Skip Hours']-df_1st_hour['Manual Skip Hours']

# %%
## insert AHT

df_1st_hour['AHT']=3600*((df_1st_hour['Manual Skip Hours']+df_1st_hour['Processed Hours'])/df_1st_hour['Processed Units'])
df_2nd_hour['AHT']=3600*((df_2nd_hour['Manual Skip Hours']+df_2nd_hour['Processed Hours'])/df_2nd_hour['Processed Units'])
df_3rd_hour['AHT']=3600*((df_3rd_hour['Manual Skip Hours']+df_3rd_hour['Processed Hours'])/df_3rd_hour['Processed Units'])
df_4th_hour['AHT']=3600*((df_4th_hour['Manual Skip Hours']+df_4th_hour['Processed Hours'])/df_4th_hour['Processed Units'])
df_5th_hour['AHT']=3600*((df_5th_hour['Manual Skip Hours']+df_5th_hour['Processed Hours'])/df_5th_hour['Processed Units'])

# %%
## combine DFs

all_df_list = [df_1st_hour,df_2nd_hour,df_3rd_hour,df_4th_hour,df_5th_hour]

##join all sheets
df = pd.concat(all_df_list)

# %%
## Merge DF
df_merge=pd.merge(df,df_tm,on="DA Login",how="left")
df_merge['Time Range'].unique()
# Out:
# array(['07-08', '08-09', '09-10', '10-11', '11-12'], dtype=object)

# %%
## Pick out necessary values

df_merge=df_merge[['DA Login','First Login Time','Processed Units','Processed Hours','Manual Skip Hours','AHT','Time Range','Shift','TM','OM']]
df_merge.head()
# Out:
#    DA Login First Login Time  Processed Units  Processed Hours  \
# 0    aanbub   9/24/2021 1:28               75           0.5475
# 1     aarjk              NaN                0           0.0000
# 2  abdarsha              NaN                0           0.0000
# 3   adithia              NaN                0           0.0000
# 4   adityna   9/24/2021 1:29               17           0.2509
#
#    Manual Skip Hours        AHT Time Range    Shift        TM        OM
# 0                0.0  26.280000      07-08  Morning     sekal  jagarekh
# 1                0.0        NaN      07-08  Morning  kkathire    mryjos
# 2                0.0        NaN      07-08  Morning     czvij  rbbashee
# 3                0.0        NaN      07-08  Morning  shawnpet    mryjos
# 4                0.0  53.131765      07-08  Morning  kkathire    mryjos

# %%
## Create Processed Units table

table_pu = pd.pivot_table(df_merge, values=['Processed Units'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'Processed Units':np.sum,} , fill_value=0)
table_pu.head()
# Out:
#            Processed Units
# Time Range           07-08 08-09 09-10 10-11 11-12 Total
# DA Login
# aanbub                  75    51    66   152   139   483
# aarjk                    0     0     0    61    60   121
# abdarsha                 0     0     0     0     0     0
# adithia                  0     0     0     5     0     5
# adityna                 17    46    98    91    63   315

# %%
## Create Manual Skips Hours table

table_ms = pd.pivot_table(df_merge, values=['Manual Skip Hours'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'Manual Skip Hours':np.sum,} , fill_value=0)
table_ms.head()
# Out:
#            Manual Skip Hours
# Time Range             07-08   08-09 09-10   10-11 11-12   Total
# DA Login
# aanbub                   0.0  0.0006   0.0  0.0000   0.0  0.0006
# aarjk                    0.0  0.0000   0.0  0.0000   0.0  0.0000
# abdarsha                 0.0  0.0000   0.0  0.0000   0.0  0.0000
# adithia                  0.0  0.0000   0.0  0.0125   0.0  0.0125
# adityna                  0.0  0.0836   0.0  0.0000   0.0  0.0836

# %%
## Create AHT table

table_aht = pd.pivot_table(df_merge, values=['AHT'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'AHT':np.mean,} , fill_value=0)
table_aht.head()
# Out:
#                   AHT                                                \
# Time Range      07-08      08-09      09-10       10-11       11-12
# DA Login
# aanbub      26.280000  69.254118  91.685455   63.928421   94.793957
# aarjk        0.000000   0.000000   0.000000   31.750820   59.052000
# adithia      0.000000   0.000000   0.000000   59.616000         inf
# adityna     53.131765  74.316522  63.323265  107.280000  207.360000
# aharinat     1.447552  19.371340  30.667119   48.203670  156.240000
#
#
# Time Range       Total
# DA Login
# aanbub       69.188390
# aarjk        45.401410
# adithia            inf
# adityna     101.082310
# aharinat     51.185936

# %%
## All KPI Table

table = pd.pivot_table(df_merge, values=['Processed Units','Processed Hours','Manual Skip Hours','AHT'], index=['DA Login','Time Range'],margins=True,
               margins_name='Total', aggfunc={'Processed Units':np.sum,
                                                        'Processed Hours':np.sum,
                                                        'Manual Skip Hours':np.sum,
                                                        'AHT':np.mean,} , fill_value=0)
table.head()
# Out:
#                            AHT  Manual Skip Hours  Processed Hours  \
# DA Login Time Range
# aanbub   07-08       26.280000             0.0000           0.5475
#          08-09       69.254118             0.0006           0.9805
#          09-10       91.685455             0.0000           1.6809
#          10-11       63.928421             0.0000           2.6992
#          11-12       94.793957             0.0000           3.6601
#
#                      Processed Units
# DA Login Time Range
# aanbub   07-08                    75
#          08-09                    51
#          09-10                    66
#          10-11                   152
#          11-12                   139

# %%
## create list for email iteration

list=df_merge['DA Login'].unique()
list=list[0:3]
len(list)
# Out:
# 3

# %%
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')

    
for i in range (0,len(list)):
    
    
    
    table_pu = pd.pivot_table(df_merge, values=['Processed Units'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'Processed Units':np.sum,} , fill_value=0)
    
    table_ms = pd.pivot_table(df_merge, values=['Manual Skip Hours'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'Manual Skip Hours':np.sum,} , fill_value=0)
    
    table_aht = pd.pivot_table(df_merge, values=['AHT'], index=['DA Login'],columns=['Time Range'],margins=True,
               margins_name='Total', aggfunc={'AHT':np.mean,} , fill_value=0) 

    pd.set_option('display.max_rows', df_merge.shape[0]+1)

    mail = outlook.CreateItem(0)

    mail.Subject = 'ADS Hourly Throughput Summary Report'
    mail.To= 'arvinmvn@amazon.com'
    #mail.To = list[i]+'@amazon.com' 
    #mail.CC = table_process_count.index.get_level_values('Level 1 Manager')[j] + '@amazon.com'
        
    
## i-> position of data in dataframe
    mail.HTMLBody =f"""<h3>{'Hi ' + list[i]}</h3> """ + f"""<h3>PFB Hourly summary upto to {df_5th_hour['Time Range'].unique()} </h3>""" + '''<h3>Processed Units Table:-</h3>
                   {}'''.format(table_pu[i:i+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render())+ '''<h3>Manual Skip Hours Table:-</h3>
                   {}'''.format(table_ms[i:i+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render()) + '''<h3>AHT Table:-</h3>
                   {}'''.format(table_aht[i:i+1].style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render()) + '''<h3> Thanks and Regards </h3>''' + '''<h3> Arvinth M.V.N </h3>'''
  
  
    mail.Send()

# %%
## Store output for next iteration

df_merge.to_excel(r'C:\Users\arvinmvn\Desktop\Hourly Output Folder\11_12.xlsx',index=False)
